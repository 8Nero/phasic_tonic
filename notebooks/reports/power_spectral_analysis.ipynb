# %%
from src.DataFolder import DataFolder
from src.NeuralSignal import NeuralSignal
from src.runtime_logger import logger_setup

import yaml
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from neurodsp.spectral import compute_spectrum

data_path = "/home/miranjo/phasic_tonic/data/processed"
config_path = "/home/miranjo/phasic_tonic/configs/test.yaml"

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Load the config file

# %%
with open(config_path, 'r') as f:
    args = yaml.safe_load(f)

fs                  = args.pop("fs")
f_theta             = (args.pop("f_theta_lower"), args.pop("f_theta_upper"))
f_lowpass           = args.pop("f_lowpass")
lowpass_length      = args.pop("lowpass_length")
bandpass_length     = args.pop("bandpass_length")
threshold_bycycle   = args.pop("threshold_bycycle")
threshold_episode   = args.pop("threshold_episode")

# Start logger
logger = logger_setup()

# %% [markdown]
# ### Load the dataset

# %%
remFolder = DataFolder(data_path)

# %% [markdown]
# ## Sample analysis

# %%
sig = remFolder[3]["data"][0]
sig = NeuralSignal(sig, fs)
sig.filter("lowpass", f_lowpass, lowpass_length)
sig.filter("bandpass", f_theta, bandpass_length)
sig.segment(f_theta, threshold_episode, threshold_bycycle)

# %%
remFolder[0]
# Out:
# {'data': [array([ 61.01857125,  74.5644424 ,  68.13499889, ..., 119.73799059,
#          102.96597314,  74.88627699]),
#   array([387.51393371, 380.7564102 , 356.24890884, ..., 196.04994604,
#          171.04399988, 140.05175519]),
#   array([-301.93244099, -267.38818651, -298.89216358, ...,  123.46875137,
#           114.95635819,  120.97632871]),
#   array([-57.29559224,   8.43477511,  86.5613023 , ..., -17.53177742,
#           17.26631024,  24.28252164])],
#  'metadata': {'RatID': 'Rat2',
#   'StudyDay': 'SD4',
#   'condition': 'HC',
#   'treatment': '2',
#   'posttrial_number': 'posttrial1'}}

# %%
#Combining all episodes

if sig.phasic:
    phasic = np.concatenate(sig.get_phasic("raw"))
    f, spectrum_phasic = compute_spectrum(phasic, sig.fs, method='welch', avg_type='mean')
tonic = np.concatenate(sig.get_tonic("raw"))
f, spectrum_tonic = compute_spectrum(tonic, sig.fs, method='welch', avg_type='mean')

# %%
plt.plot(spectrum_phasic[:100])
plt.plot(spectrum_tonic[:100])

plt.axvline(x=4-1, color='r', linestyle='--', linewidth=1)
plt.axvline(x=12-1, color='r', linestyle='--', linewidth=1)

plt.yscale('log')

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Dataset

# %%
spectrum_phasic = []
spectrum_tonic = []

for sample in remFolder:
    lfpREMs = sample["data"]
    metadata = sample["metadata"]

    for lfpREM in lfpREMs:
        if not( int(metadata["treatment"]) == 1):
            continue

        if(len(lfpREM) < 2500): 
            break    #Skip when the duration is less than a second
        
        theta = NeuralSignal(lfpREM, fs)
        theta.filter('lowpass', f_range=f_lowpass, n_seconds=lowpass_length)
        theta.segment(f_range=f_theta, threshold_episode=threshold_episode, threshold_bycycle=threshold_bycycle)
        
        # Combine all tonic episodes for each REM period
        theta_tonic = np.concatenate(theta.get_tonic(filter_type="raw"))
        logger.debug("tonic shape: {0}".format(theta_tonic.shape))
        
        f, spectrum_t = compute_spectrum(theta_tonic, theta.fs, method='welch', avg_type='mean')
        spectrum_tonic.append(spectrum_t[:100])

        if theta.phasic:
            # Combine all phasic episodes for each REM period
            theta_phasic = np.concatenate(theta.get_phasic(filter_type="raw"))
            logger.debug("signal shape: {0}".format(theta_phasic.shape))
            
            f, spectrum_p = compute_spectrum(theta_phasic, theta.fs, method='welch', avg_type='mean')
            spectrum_phasic.append(spectrum_p[:100])
            

spectrum_phasic = np.vstack(spectrum_phasic)
spectrum_tonic = np.vstack(spectrum_tonic)

phasic_spectrum_mean = np.mean(spectrum_phasic, axis=0)
tonic_spectrum_mean = np.mean(spectrum_tonic, axis=0)

phasic_spectrum_std = np.std(spectrum_phasic, axis=0)
tonic_spectrum_std = np.std(spectrum_tonic, axis=0)
# Out:
# /home/miranjo/.local/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 2500 is greater than input length  = 2264, using nperseg = 2264
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /home/miranjo/.local/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 2500 is greater than input length  = 2354, using nperseg = 2354
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /home/miranjo/.local/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 2500 is greater than input length  = 2127, using nperseg = 2127
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /home/miranjo/.local/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 2500 is greater than input length  = 2244, using nperseg = 2244
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /home/miranjo/.local/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 2500 is greater than input length  = 1988, using nperseg = 1988
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /home/miranjo/.local/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 2500 is greater than input length  = 2434, using nperseg = 2434
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /home/miranjo/.local/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 2500 is greater than input length  = 1782, using nperseg = 1782
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /home/miranjo/.local/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 2500 is greater than input length  = 2449, using nperseg = 2449
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /home/miranjo/.local/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 2500 is greater than input length  = 2486, using nperseg = 2486
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /home/miranjo/.local/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 2500 is greater than input length  = 2362, using nperseg = 2362
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /home/miranjo/.local/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 2500 is greater than input length  = 2401, using nperseg = 2401
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /home/miranjo/.local/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 2500 is greater than input length  = 2322, using nperseg = 2322
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /home/miranjo/.local/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 2500 is greater than input length  = 1765, using nperseg = 1765
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /home/miranjo/.local/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 2500 is greater than input length  = 2407, using nperseg = 2407
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /home/miranjo/.local/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 2500 is greater than input length  = 2426, using nperseg = 2426
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /home/miranjo/.local/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 2500 is greater than input length  = 2414, using nperseg = 2414
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /home/miranjo/.local/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 2500 is greater than input length  = 1925, using nperseg = 1925
#   warnings.warn('nperseg = {0:d} is greater than input length '

# %%
phasic_spectrum_err = phasic_spectrum_std/(len(spectrum_phasic)**0.5)
tonic_spectrum_err = tonic_spectrum_std/(len(spectrum_tonic)**0.5)

# %%
plt.figure(figsize=(12,8))
plt.plot(phasic_spectrum_mean)
plt.plot(tonic_spectrum_mean)

plt.fill_between(np.arange(100), phasic_spectrum_mean - phasic_spectrum_err,
                 phasic_spectrum_mean + phasic_spectrum_err, 
                 alpha=0.5, label='Standard Deviation of Phasic Spectrum')

plt.fill_between(np.arange(100), tonic_spectrum_mean - tonic_spectrum_err,
                 tonic_spectrum_mean + tonic_spectrum_err, 
                 alpha=0.5, label='Standard Deviation of Tonic Spectrum')

plt.xlabel('Frequency (Hz)', fontsize=14)
plt.ylabel('Power [dB]', fontsize=14)

plt.yscale('log')
plt.xscale('log')

plt.xlim((1, 101))

plt.axvline(x=4, color='purple', linestyle='--')
plt.axvline(x=12, color='purple', linestyle='--')

plt.title('Power spectrum (Welch)', fontsize=16)
plt.legend(['Phasic', 'Tonic'])

# %%
plt.figure(figsize=(8,8))
plt.plot(phasic_spectrum_mean[:45])
plt.plot(tonic_spectrum_mean[:45])

#plt.fill_between(freq, phasic_spectrum_mean - phasic_spectrum_std,
#                 phasic_spectrum_mean + phasic_spectrum_std, 
#                 alpha=0.5, label='Standard Deviation of Phasic Spectrum')
#
#plt.fill_between(freq, tonic_spectrum_mean - tonic_spectrum_std,
#                 tonic_spectrum_mean + tonic_spectrum_std, 
#                 alpha=0.5, label='Standard Deviation of Tonic Spectrum')

plt.xlabel('Frequency (Hz)', fontsize=14)
plt.ylabel('Power [dB]', fontsize=14)

plt.yscale('log')

plt.xlim((1, 46))

plt.axvline(x=4, color='purple', linestyle='--')
plt.axvline(x=12, color='purple', linestyle='--')

plt.title('Power spectrum (Welch)', fontsize=16)
plt.legend(['Phasic', 'Tonic'])

# %%
plt.figure(figsize=(4,6))
plt.boxplot([phasic_spectrum_mean[4:12]/phasic_spectrum_mean[4:12].max(),
             tonic_spectrum_mean[4:12]/phasic_spectrum_mean[4:12].max()],
            labels=["Phasic", "Tonic"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fbb09a44430>,
#   <matplotlib.lines.Line2D at 0x7fbb09a44700>,
#   <matplotlib.lines.Line2D at 0x7fbb09a457e0>,
#   <matplotlib.lines.Line2D at 0x7fbb09a45ab0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fbb09a449d0>,
#   <matplotlib.lines.Line2D at 0x7fbb09a44ca0>,
#   <matplotlib.lines.Line2D at 0x7fbb09a45d80>,
#   <matplotlib.lines.Line2D at 0x7fbb09a46050>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fbb09a44160>,
#   <matplotlib.lines.Line2D at 0x7fbb09a45510>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fbb09a44f70>,
#   <matplotlib.lines.Line2D at 0x7fbb09a46320>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fbb09a45240>,
#   <matplotlib.lines.Line2D at 0x7fbb09a465f0>],
#  'means': []}

# %%
df_phasic = pd.DataFrame(phasic_spectrum_mean)
df_tonic  = pd.DataFrame(tonic_spectrum_mean)

df_phasic.to_excel("spectrum_phasic.xlsx")
df_tonic.to_excel("spectrum_tonic.xlsx")
