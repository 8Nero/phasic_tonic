# %%
from src.utils import DataFolder
from src import Signal
from src.utils.helper import load_config

import numpy as np
import pandas as pd

data_path = "/home/miranjo/phasic_tonic/processed"
config_path = "/home/miranjo/phasic_tonic/configs/test.yaml"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_9762/3575018257.py in <module>
# ----> 1 from src.utils import DataFolder
#       2 from src import Signal
#       3 from src.utils.helper import load_config
#       4
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'src.utils'

# %%
# Out:
# {'fs': 2500,
#  'f_theta_lower': 4,
#  'f_theta_upper': 12,
#  'f_lowpass': 25,
#  'n_seconds_filter': 0.5,
#  'n_seconds_theta': 0.75,
#  'threshold_kwargs': {'amp_fraction_threshold': 0.8,
#   'amp_consistency_threshold': 0,
#   'period_consistency_threshold': 0,
#   'monotonicity_threshold': 0,
#   'min_n_cycles': 8}}
